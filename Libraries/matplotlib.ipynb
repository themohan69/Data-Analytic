# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data
dataX = [1, 2, 3, 4, 5]
dataY = [6, 7, 8, 9, 10]

# %%
plt.bar(dataX, dataY)
plt.xlabel("x-axis label")
plt.ylabel("y-axis label")
plt.title("Sample bar plot")
plt.show()

# %%
import pandas as pd

# %%
data = pd.read_excel("empolyee-Performance-Data.xlsx")

# %%
data.head()
# Out:
#   Employee Name  Q1 Performance (%)  Q2 Performance (%)  Q3 Performance (%)  \
# 0         Alice                  85                  88                  90
# 1           Bob                  78                  82                  79
# 2       Charlie                  92                  91                  95
# 3         Diana                  88                  85                  89
# 4           Eve                  75                  80                  82
#
#    Q4 Performance (%)
# 0                  87
# 1                  85
# 2                  94
# 3                  90
# 4                  77

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee Name       22 non-null     object
#  1   Q1 Performance (%)  22 non-null     int64
#  2   Q2 Performance (%)  22 non-null     int64
#  3   Q3 Performance (%)  22 non-null     int64
#  4   Q4 Performance (%)  22 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1012.0+ bytes

# %%
mean_value = data[["Q1 Performance (%)", "Q2 Performance (%)", "Q3 Performance (%)", "Q4 Performance (%)"]].mean()
median_value = data[["Q1 Performance (%)", "Q2 Performance (%)", "Q3 Performance (%)", "Q4 Performance (%)"]].median()

# %%
print("Mean")
print(mean_value)
print()
print("Median")
print(median_value)
# Out:
# Mean
# Q1 Performance (%)    52.000000
# Q2 Performance (%)    52.318182
# Q3 Performance (%)    51.409091
# Q4 Performance (%)    45.909091
# dtype: float64
#
# Median
# Q1 Performance (%)    49.0
# Q2 Performance (%)    47.5
# Q3 Performance (%)    47.5
# Q4 Performance (%)    36.0
# dtype: float64

# %%
quarterly_avg = data.mean(numeric_only=True)
plt.figure(figsize=(8, 5))
sns.barplot(x=quarterly_avg.index, y=quarterly_avg.values, palette="viridis")
plt.title("Average Perfomance Across Quarters")
plt.ylabel("Perfomance (%)")
plt.xlabel("Quarters")                                                                                                             
plt.show()
# Out:
# C:\Users\PC-2\AppData\Local\Temp\ipykernel_1624\3286418833.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=quarterly_avg.index, y=quarterly_avg.values, palette="viridis")

# %%
df_melted = data.melt(id_vars=["Employee Name"], var_name="Quarter", value_name="Performance")

plt.figure(figsize=(15, 7))
sns.lineplot(data=df_melted, x="Quarter", y="Performance", hue="Employee Name", marker="s")
plt.title("Performance Trends of Employee Across Quarters")
plt.ylabel("Performance (%)")
plt.xlabel("Quarters")
plt.legend(title="Employee Name")
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df_melted, x="Quarter", y="Performance", palette="Set2")
plt.title("Perfomance Distribution Across Quarters")
plt.ylabel("Perfomance (%)")
plt.xlabel("Quarters")
plt.show()
# Out:
# C:\Users\PC-2\AppData\Local\Temp\ipykernel_1624\3007318814.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_melted, x="Quarter", y="Performance", palette="Set2")
